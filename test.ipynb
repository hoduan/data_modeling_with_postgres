# %%
import pandas as pd
import psycopg2 

conn = psycopg2.connect("host=127.0.0.1 dbname=hduan user=hduan password=testing")
cur = conn.cursor()
conn.set_session(autocommit=True)

# %%
query="""select * from dim_users where level='paid'"""
df = pd.read_sql(query, con=conn)
df.head()
# Out:
#    user_id  first_name last_name gender level
# 0       44      Aleena     Kirby      F  paid
# 1       80       Tegan    Levine      F  paid
# 2       29  Jacqueline     Lynch      F  paid
# 3       25      Jayden    Graves      M  paid
# 4       73       Jacob     Klein      M  paid

# %%
query="""select count(*) from dim_users"""
df = pd.read_sql(query, con=conn)
df.head()
# Out:
#    count
# 0     86

# %%
query="""select * from dim_users"""
df = pd.read_sql(query, con=conn)
df.head()
# Out:
#    user_id first_name  last_name gender level
# 0       69   Anabelle    Simpson      F  free
# 1       32       Lily      Burns      F  free
# 2       75     Joseph  Gutierrez      M  free
# 3       92      Ryann      Smith      F  free
# 4       49      Chloe     Cuevas      F  free

# %%
query="""select count(*) from dim_songs"""
df = pd.read_sql(query, con=conn)
df.head()
# Out:
#    count
# 0     70

# %%
query="""select title from dim_songs where year != 0"""
df = pd.read_sql(query, con=conn)
df.head()
# Out:
#                   title
# 0       Something Girls
# 1            Pink World
# 2        Face the Ashes
# 3             Soul Deep
# 4  Crazy Mixed Up World

# %%
query="""select count(*) from dim_times"""
df = pd.read_sql(query, con=conn)
df.head()
# Out:
#    count
# 0   4221

# %%
query="""select * from dim_times limit 10"""
df = pd.read_sql(query, con=conn)
df.head()
# Out:
#                start_time  hour  day  week  month  year  weekday
# 0 2018-11-11 02:33:56.796     2  315    45     11  2018        6
# 1 2018-11-11 02:36:10.796     2  315    45     11  2018        6
# 2 2018-11-11 02:40:34.796     2  315    45     11  2018        6
# 3 2018-11-11 04:36:13.796     4  315    45     11  2018        6
# 4 2018-11-11 04:36:46.796     4  315    45     11  2018        6

# %%
query="""select count(*) from dim_artists"""
df = pd.read_sql(query, con=conn)
df.head()
# Out:
#    count
# 0     68

# %%
query="""select * from dim_artists limit 10"""
df = pd.read_sql(query, con=conn)
df.head()
# Out:
#             artist_id                   name                     location  \
# 0  AR7G5I41187FB4CE6C               Adam Ant              London, England
# 1  AR8ZCNI1187B9A069B       Planet P Project
# 2  ARXR32B1187FB57099                    Gob
# 3  AR10USD1187B99F3F1  Tweeterfriendly Music  Burlington, Ontario, Canada
# 4  ARMJAGH1187FB546F3           The Box Tops                  Memphis, TN
#
#    latitude  longitude
# 0
# 1
# 2
# 3
# 4  35.14968  -90.04892

# %%
query="""select * from fct_songplays"""
df = pd.read_sql(query, con=conn)
df.head()
# Out:
#    songplay_id              start_time  user_id level             song_id  \
# 0            1 2018-11-01 22:23:14.796      101  free  SONHOTT12A8C13493C
#
#             artist_id  session_id                  location  \
# 0  AR7G5I41187FB4CE6C         100  New Orleans-Metairie, LA
#
#                                           user_agent
# 0  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...

# %%
query="""SELECT * 
FROM fct_songplays JOIN dim_songs ON fct_songplays.song_id = dim_songs.song_id
JOIN dim_artists ON fct_songplays.artist_id = dim_artists.artist_id
JOIN dim_times ON fct_songplays.start_time =  dim_times.start_time 
JOIN dim_users ON fct_songplays.user_id = dim_users.user_id 
LIMIT 5;"""
df = pd.read_sql(query, con=conn)
df.head()
# Out:
#    songplay_id              start_time user_id level             song_id  \
# 0            1 2018-11-01 22:23:14.796     101  free  SONHOTT12A8C13493C
#
#             artist_id  session_id                  location  \
# 0  AR7G5I41187FB4CE6C         100  New Orleans-Metairie, LA
#
#                                           user_agent             song_id  ...  \
# 0  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...  SONHOTT12A8C13493C  ...
#
#    day week  month  year weekday user_id first_name last_name gender level
# 0  305   44     11  2018       3     101     Jayden       Fox      M  free
#
# [1 rows x 31 columns]

# %%
conn.close()
